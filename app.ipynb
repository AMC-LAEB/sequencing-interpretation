# %% [markdown]
# Click 'Run all' in the toolbar above to generate the interactive app. Please note it will take a few seconds to appear.

# %%
# %config InlineBackend.figure_format = 'retina'
# !wget -q https://raw.githubusercontent.com/AMC-LAEB/sequencing-interpretation/main/backend.py
import backend
# !{backend.wget_call}
backend.lr_model, backend.lr_scaler, backend.inc_model, backend.inc_scaler = backend.load_models()
layout, interactive = backend.create_ui()
display(layout, interactive)
# Out:
#   <style>
#   .widget-slider .ui-slider-horizontal {
#     height: 12px !important;  /* increase thickness */
#     margin-top: 15px !important; /* adjust vertical position if needed */
#   }
#
#   .widget-slider .ui-slider-horizontal .ui-slider-handle {
#     top: -5px !important;  /* center handle vertically */
#     height: 24px !important;  /* bigger handle */
#     width: 24px !important;
#     margin-left: -12px !important;
#   }
# ...
# Output()
